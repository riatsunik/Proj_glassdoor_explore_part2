# %% [markdown]
# # Explorando arquivo de texto
# https://medium.com/ibm-data-science-experience/markdown-for-jupyter-notebooks-cheatsheet-386c05aeebed

# %% [markdown]
# ## Introdução
# O Script abaixo é a continuação do projeto, que tem como objetivo analisar a frequência das palavras chaves que aparecem nas descrições de empregos de data science do site Glassdoor através de visualizações simples como nuvem de palavras e outputs de funções.
#
# Na <a href="">primeira parte </a>utilizamos um web crawler para capturar todos os dados referentes as vagas de data science dos Estados Unidos e armazenamos em um arquivo csv, agora vamos trabalhar os textos que aparecem nas descrições das vagas.
#
# Algumas das funções foram adaptadas do exercício do Kaggle <a href="https://www.kaggle.com/c/word2vec-nlp-tutorial#part-1-for-beginners-bag-of-words"> 'Bag of Words Meets Bags of Popcorn' Part 1</a>

# %% [markdown]
# ### Importações
# - Pandas para trabalhar o arquivo.
# - nltk biblioteca para trabalhar com liguagem humana
# - pyplot e wordcloud para visualização
# - collections, re para manipulação dos dados

# %%
import pandas as pd
import nltk
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import collections, re
#nltk.download()

# %% [markdown]
# #### Manipulação do arquivo
#
# - Vamos iniciar lendo o arquivo, em seguida vamos ver a quantidade de linhas x colunas e por fim os nomes das colunas.O arquivo está disponível para download nesse <a href="">link</a> e o mesmo deve estar na mesma pasta do Script.

# %%
book = pd.read_csv('booksdata.csv')
print(book.shape)
print(book.columns.values)
# Out:
# (898, 5)
# ['title' 'local' 'company_name' 'salary' 'description']

# %% [markdown]
# - Se seu resultado for igual ao output acima então podemos prosseguir, armazenando a coluna que nos interessa 'description' (descrição das vagas de emprego).

# %%
description_text = book['description']

# %% [markdown]
# #### Função para limpar os textos
#
# - Conforme vimos nas seções anteriores temos um total de 898 descrições de vagas, para poder tratar uma a uma precisamos criar uma função que possa ser chamada varias vezes. Os detalhes das funções estão comentadas seguidas da "#".

# %%
def description_to_words( raw_description ):
    # Function to convert a raw review to a string of words
    # The input is a single string (a raw movie review), and 
    # the output is a single string (a preprocessed movie review)
    #
    # 1. Remove HTML
    description_text = BeautifulSoup(raw_description,"lxml").get_text() 
    #
    # 2. Remove non-letters        
    letters_only = re.sub("[^a-zA-Z]", " ", description_text) 
    #
    # 3. Convert to lower case, split into individual words
    words = letters_only.lower().split()                             
    #
    # 4. In Python, searching a set is much faster than searching
    #   a list, so convert the stop words to a set
    stops = set(nltk.corpus.stopwords.words('english'))                
    # 
    # 5. Remove stop words
    meaningful_words = [w for w in words if not w in stops]   
    #
    # 6. Join the words back into one string separated by space, 
    # and return the result.
    return( " ".join( meaningful_words ))

# %%
clean_description = description_to_words(description_text[0])
print (clean_description)
# Out:
# credit karma fast growing data sciences team seeking experienced senior data scientist role allow motivated individual make significant impact across organization delivering relevant content users helping drive accelerated revenue growth job entails partner stakeholders across organization identify highimpact opportunities leverage extensive data better serve users drive creation comprehensive datasets encompassing user profiles behaviors incorporating wide variety signals data types assess potential usefulness validity new statistical approaches data sources build complex predictive models substantially improve continuously optimize user engagement revenue generation rapidly develop proofofconcept prototypes prove hypotheses reach across multiple functions product management data engineering implement models production monitor performance motivate mentor data scientists grow skills careers ideal candidate advanced degree phdms statistics related quantitative discipline years experie
# ...

# %%
# Get the number of reviews based on the dataframe column size
num_description = description_text.size
print(num_description)
# Out:
# 898

# %%
# Initialize an empty list to hold the clean reviews
clean_train_description = []

# %%
# Loop over each review; create an index i that goes from 0 to the length
# of the movie review list 
for i in range( 0, num_description ):
    # Call our function for each one, and add the result to the list of
    # clean reviews
    clean_train_description.append( description_to_words( description_text[i] ) )

# %%
##### WORDCLOUD ####

# %%
stopwords = set(nltk.corpus.stopwords.words('english'))

# %%
wordcloud = WordCloud(
        background_color='white',
        stopwords=None,
        max_words=100,
        max_font_size=40, 
        scale=3,
        random_state=1 # chosen at random by flipping a coin; it was heads
    ).generate(str(clean_train_description))

# %%
fig = plt.figure(1, figsize=(12, 12))
plt.axis('off')
plt.imshow(wordcloud)
plt.show()

# %%
bagsofwords = [collections.Counter(re.findall(r'\w+', txt))
            for txt in clean_train_description]

# %%
sumbags = sum(bagsofwords, collections.Counter())

# %%
bagsofwords[0].most_common(10)
# Out:
# [('data', 9),
#  ('experience', 5),
#  ('models', 4),
#  ('across', 3),
#  ('revenue', 3),
#  ('organization', 2),
#  ('relevant', 2),
#  ('users', 2),
#  ('drive', 2),
#  ('user', 2)]

# %%
sumbags.most_common(100)
# Out:
# [('data', 9114),
#  ('experience', 4214),
#  ('business', 2480),
#  ('work', 2087),
#  ('science', 1788),
#  ('team', 1708),
#  ('analysis', 1702),
#  ('analytics', 1652),
#  ('learning', 1644),
#  ('skills', 1518),
#  ('machine', 1367),
#  ('ability', 1290),
#  ('scientist', 1210),
#  ('models', 1206),
#  ('solutions', 1148),
#  ('years', 1137),
#  ('statistical', 1125),
#  ('new', 1024),
#  ('knowledge', 996),
#  ('tools', 964),
#  ('development', 956),
#  ('company', 919),
#  ('research', 906),
#  ('using', 901),
#  ('techniques', 899),
#  ('working', 899),
#  ('statistics', 897),
#  ('strong', 896),
#  ('develop', 872),
#  ('information', 832),
#  ('including', 819),
#  ('advanced', 802),
#  ('engineering', 786),
#  ('python', 785),
#  ('modeling', 782),
#  ('degree', 763),
#  ('product', 762),
#  ('us', 739),
#  ('support', 732),
#  ('job', 730),
#  ('problems', 730),
#  ('r', 720),
#  ('technology', 713),
#  ('insights', 706),
#  ('analytical', 701),
#  ('management', 697),
# ...
